# %%
import pandas as pd
from sklearn.svm import SVC
from sklearn.model_selection import train_test_split, StratifiedKFold, GridSearchCV
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score, roc_auc_score

# %%
# Loading dataframe partitions
df = pd.read_csv('../../data/spotify_churn_dataset_transformed.csv')
X = df.drop(columns=['is_churned'])
y = df['is_churned']

# Splitting into train and test partitions
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.15, random_state=42, stratify=y)

# %%
# Initializing the SVC model
SVC_model = SVC(kernel='rbf')
SVC_model.fit(X_train, y_train)

# Getting predictions
preds = SVC_model.predict(X_test)

# %%
acc_score = accuracy_score(y_test, preds)
auc_score = roc_auc_score(y_test, preds)

print(f"Accuracy: {acc_score:0.3f}\nAUC Score: {auc_score:0.3f}")
# Out:
# Accuracy: 0.741
# AUC Score: 0.500

# %%
# Defining stratified k-fold for imbalanced dataset
strat_kfold = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

param_grid = {
    'kernel' : ['rbf', 'linear'],
    'C' : [0.1, 1, 10],
    'gamma' : ['scale', 0.01, 0.1, 1]
}

grid_search = GridSearchCV(SVC(class_weight='balanced'), param_grid, cv=strat_kfold, scoring='roc_auc', n_jobs=-1, verbose=3)
grid_search.fit(X_train, y_train)

# Best parameters from grid search
print(f"Best Parameters: {grid_search.best_params_}")
print(f"Best Score: {grid_search.best_score_}")
# Out:
# Fitting 5 folds for each of 24 candidates, totalling 120 fits
# [CV 4/5] END ....C=0.1, gamma=scale, kernel=rbf;, score=0.460 total time=   2.9s
# [CV 2/5] END .....C=0.1, gamma=0.01, kernel=rbf;, score=0.476 total time=   3.4s
# [CV 5/5] END ....C=0.1, gamma=scale, kernel=rbf;, score=0.523 total time=   3.4s
# [CV 3/5] END .....C=0.1, gamma=0.01, kernel=rbf;, score=0.461 total time=   4.2s
# [CV 1/5] END ....C=0.1, gamma=scale, kernel=rbf;, score=0.526 total time=   4.9s
# [CV 2/5] END ....C=0.1, gamma=scale, kernel=rbf;, score=0.510 total time=   5.7s
# [CV 3/5] END ....C=0.1, gamma=scale, kernel=rbf;, score=0.522 total time=   5.6s
# [CV 1/5] END ......C=0.1, gamma=0.1, kernel=rbf;, score=0.500 total time=   3.3s
# [CV 2/5] END ......C=0.1, gamma=0.1, kernel=rbf;, score=0.482 total time=   3.3s
# [CV 3/5] END ......C=0.1, gamma=0.1, kernel=rbf;, score=0.475 total time=   3.8s
# [CV 4/5] END ......C=0.1, gamma=0.1, kernel=rbf;, score=0.463 total time=   3.4s
# [CV 1/5] END ........C=0.1, gamma=1, kernel=rbf;, score=0.516 total time=   2.6s
# [CV 5/5] END .....C=0.1, gamma=0.01, kernel=rbf;, score=0.476 total time=  11.8s
# [CV 1/5] END .....C=0.1, gamma=0.01, kernel=rbf;, score=0.480 total time=  12.4s
# [CV 4/5] END .....C=0.1, gamma=0.01, kernel=rbf;, score=0.452 total time=  12.6s
# [CV 2/5] END ........C=0.1, gamma=1, kernel=rbf;, score=0.507 total time=   2.3s
# [CV 5/5] END ......C=0.1, gamma=0.1, kernel=rbf;, score=0.484 total time=   9.2s
# [CV 3/5] END ........C=0.1, gamma=1, kernel=rbf;, score=0.495 total time=   4.1s
# [CV 4/5] END ........C=0.1, gamma=1, kernel=rbf;, score=0.484 total time=   6.6s
# [CV 5/5] END ........C=0.1, gamma=1, kernel=rbf;, score=0.472 total time=   7.0s
# [CV 5/5] END .C=0.1, gamma=scale, kernel=linear;, score=0.509 total time= 4.8min
# [CV 5/5] END ..C=0.1, gamma=0.01, kernel=linear;, score=0.509 total time= 4.8min
# [CV 1/5] END ......C=1, gamma=scale, kernel=rbf;, score=0.526 total time=   2.7s
# [CV 2/5] END ......C=1, gamma=scale, kernel=rbf;, score=0.506 total time=   2.7s
# [CV 3/5] END ......C=1, gamma=scale, kernel=rbf;, score=0.509 total time=   1.4s
# [CV 4/5] END ......C=1, gamma=scale, kernel=rbf;, score=0.462 total time=   1.3s
# [CV 5/5] END ......C=1, gamma=scale, kernel=rbf;, score=0.521 total time=   2.8s
# [CV 2/5] END ..C=0.1, gamma=0.01, kernel=linear;, score=0.501 total time= 5.0min
# [CV 5/5] END .....C=0.1, gamma=1, kernel=linear;, score=0.509 total time= 4.7min
# [CV 2/5] END .C=0.1, gamma=scale, kernel=linear;, score=0.501 total time= 5.0min
# [CV 5/5] END ...C=0.1, gamma=0.1, kernel=linear;, score=0.509 total time= 4.9min
# [CV 1/5] END .......C=1, gamma=0.01, kernel=rbf;, score=0.501 total time=   3.8s
# [CV 2/5] END ...C=0.1, gamma=0.1, kernel=linear;, score=0.501 total time= 5.0min
# [CV 2/5] END .......C=1, gamma=0.01, kernel=rbf;, score=0.487 total time=   3.2s
# [CV 4/5] END .......C=1, gamma=0.01, kernel=rbf;, score=0.469 total time=   3.2s
# [CV 3/5] END .......C=1, gamma=0.01, kernel=rbf;, score=0.468 total time=   6.7s
# [CV 5/5] END .......C=1, gamma=0.01, kernel=rbf;, score=0.488 total time=   3.0s
# [CV 2/5] END .....C=0.1, gamma=1, kernel=linear;, score=0.501 total time= 5.1min
# [CV 1/5] END ..C=0.1, gamma=0.01, kernel=linear;, score=0.536 total time= 6.4min
# [CV 1/5] END ...C=0.1, gamma=0.1, kernel=linear;, score=0.536 total time= 6.4min
# [CV 1/5] END .C=0.1, gamma=scale, kernel=linear;, score=0.536 total time= 6.6min
# [CV 1/5] END ........C=1, gamma=0.1, kernel=rbf;, score=0.500 total time=   3.3s
# [CV 2/5] END ........C=1, gamma=0.1, kernel=rbf;, score=0.488 total time=   3.3s
# [CV 3/5] END ........C=1, gamma=0.1, kernel=rbf;, score=0.484 total time=   3.4s
# [CV 4/5] END ........C=1, gamma=0.1, kernel=rbf;, score=0.472 total time=   3.3s
# [CV 5/5] END ........C=1, gamma=0.1, kernel=rbf;, score=0.481 total time=   4.2s
# [CV 1/5] END .....C=0.1, gamma=1, kernel=linear;, score=0.536 total time= 6.7min
# [CV 3/5] END ..C=0.1, gamma=0.01, kernel=linear;, score=0.514 total time= 8.3min
# [CV 3/5] END ...C=0.1, gamma=0.1, kernel=linear;, score=0.514 total time= 8.3min
# [CV 3/5] END .....C=0.1, gamma=1, kernel=linear;, score=0.514 total time= 8.2min
# [CV 3/5] END .C=0.1, gamma=scale, kernel=linear;, score=0.514 total time= 8.6min
# [CV 1/5] END ..........C=1, gamma=1, kernel=rbf;, score=0.516 total time=   3.3s
# [CV 2/5] END ..........C=1, gamma=1, kernel=rbf;, score=0.507 total time=   3.4s
# [CV 3/5] END ..........C=1, gamma=1, kernel=rbf;, score=0.495 total time=   3.8s
# [CV 4/5] END ..........C=1, gamma=1, kernel=rbf;, score=0.484 total time=   4.5s
# [CV 5/5] END ..........C=1, gamma=1, kernel=rbf;, score=0.472 total time=   3.5s
# [CV 4/5] END .....C=0.1, gamma=1, kernel=linear;, score=0.477 total time= 9.3min
# [CV 2/5] END ...C=1, gamma=scale, kernel=linear;, score=0.516 total time= 4.8min
# [CV 4/5] END ...C=0.1, gamma=0.1, kernel=linear;, score=0.477 total time= 9.7min
# [CV 4/5] END .C=0.1, gamma=scale, kernel=linear;, score=0.477 total time=10.0min
# [CV 4/5] END ..C=0.1, gamma=0.01, kernel=linear;, score=0.477 total time=10.1min
# [CV 1/5] END .....C=10, gamma=scale, kernel=rbf;, score=0.525 total time=   3.1s
# [CV 2/5] END .....C=10, gamma=scale, kernel=rbf;, score=0.497 total time=   3.0s
# [CV 2/5] END ....C=1, gamma=0.01, kernel=linear;, score=0.516 total time= 5.0min
# [CV 3/5] END .....C=10, gamma=scale, kernel=rbf;, score=0.500 total time=   3.1s
# [CV 4/5] END .....C=10, gamma=scale, kernel=rbf;, score=0.457 total time=   3.1s
# [CV 5/5] END .....C=10, gamma=scale, kernel=rbf;, score=0.521 total time=   3.0s
# [CV 1/5] END ...C=1, gamma=scale, kernel=linear;, score=0.538 total time= 5.4min
# [CV 5/5] END ...C=1, gamma=scale, kernel=linear;, score=0.511 total time= 5.6min
# [CV 1/5] END ....C=1, gamma=0.01, kernel=linear;, score=0.538 total time= 5.5min
# [CV 4/5] END ...C=1, gamma=scale, kernel=linear;, score=0.475 total time= 6.5min
# [CV 1/5] END ......C=10, gamma=0.01, kernel=rbf;, score=0.512 total time=   4.6s
# [CV 2/5] END ......C=10, gamma=0.01, kernel=rbf;, score=0.483 total time=   5.0s
# [CV 3/5] END ......C=10, gamma=0.01, kernel=rbf;, score=0.473 total time=   7.3s
# [CV 2/5] END .....C=1, gamma=0.1, kernel=linear;, score=0.516 total time= 5.0min
# [CV 5/5] END ......C=10, gamma=0.01, kernel=rbf;, score=0.486 total time=   3.2s
# [CV 4/5] END ......C=10, gamma=0.01, kernel=rbf;, score=0.463 total time=   8.0s
# [CV 5/5] END ....C=1, gamma=0.01, kernel=linear;, score=0.511 total time= 5.5min
# [CV 1/5] END .....C=1, gamma=0.1, kernel=linear;, score=0.538 total time= 5.5min
# [CV 4/5] END ....C=1, gamma=0.01, kernel=linear;, score=0.475 total time= 6.5min
# [CV 5/5] END .....C=1, gamma=0.1, kernel=linear;, score=0.511 total time= 5.6min
# [CV 1/5] END .......C=10, gamma=0.1, kernel=rbf;, score=0.505 total time=   5.4s
# [CV 2/5] END .......C=10, gamma=0.1, kernel=rbf;, score=0.500 total time=   9.9s
# [CV 3/5] END .......C=10, gamma=0.1, kernel=rbf;, score=0.487 total time=   4.6s
# [CV 2/5] END .......C=1, gamma=1, kernel=linear;, score=0.516 total time= 4.7min
# [CV 1/5] END .......C=1, gamma=1, kernel=linear;, score=0.538 total time= 5.6min
# [CV 4/5] END .......C=10, gamma=0.1, kernel=rbf;, score=0.466 total time=   6.5s
# [CV 5/5] END .......C=10, gamma=0.1, kernel=rbf;, score=0.481 total time=   9.6s
# [CV 4/5] END .....C=1, gamma=0.1, kernel=linear;, score=0.475 total time= 6.4min
# [CV 5/5] END .......C=1, gamma=1, kernel=linear;, score=0.511 total time= 5.7min
# [CV 4/5] END .......C=1, gamma=1, kernel=linear;, score=0.475 total time= 6.4min
# [CV 1/5] END .........C=10, gamma=1, kernel=rbf;, score=0.516 total time=   1.7s
# [CV 2/5] END .........C=10, gamma=1, kernel=rbf;, score=0.507 total time=   3.1s
# [CV 3/5] END .........C=10, gamma=1, kernel=rbf;, score=0.495 total time=   3.1s
# [CV 4/5] END .........C=10, gamma=1, kernel=rbf;, score=0.484 total time=   3.1s
# [CV 5/5] END .........C=10, gamma=1, kernel=rbf;, score=0.472 total time=   3.2s
# [CV 3/5] END ...C=1, gamma=scale, kernel=linear;, score=0.511 total time=11.5min
# [CV 3/5] END ....C=1, gamma=0.01, kernel=linear;, score=0.511 total time=11.9min
# [CV 1/5] END ..C=10, gamma=scale, kernel=linear;, score=0.462 total time= 7.4min
# [CV 1/5] END ...C=10, gamma=0.01, kernel=linear;, score=0.462 total time= 7.4min
# [CV 2/5] END ..C=10, gamma=scale, kernel=linear;, score=0.499 total time= 9.1min
# [CV 3/5] END .....C=1, gamma=0.1, kernel=linear;, score=0.511 total time=11.4min
# [CV 4/5] END ..C=10, gamma=scale, kernel=linear;, score=0.476 total time= 9.4min
# [CV 2/5] END ...C=10, gamma=0.01, kernel=linear;, score=0.499 total time= 8.8min
# [CV 3/5] END .......C=1, gamma=1, kernel=linear;, score=0.511 total time=11.4min
# [CV 1/5] END ....C=10, gamma=0.1, kernel=linear;, score=0.462 total time= 7.1min
# [CV 4/5] END ...C=10, gamma=0.01, kernel=linear;, score=0.476 total time= 9.3min
# [CV 5/5] END ..C=10, gamma=scale, kernel=linear;, score=0.513 total time=11.5min
# [CV 2/5] END ....C=10, gamma=0.1, kernel=linear;, score=0.499 total time= 8.4min
# [CV 3/5] END ..C=10, gamma=scale, kernel=linear;, score=0.510 total time=12.6min
# [CV 1/5] END ......C=10, gamma=1, kernel=linear;, score=0.462 total time= 6.6min
# [CV 4/5] END ....C=10, gamma=0.1, kernel=linear;, score=0.476 total time= 8.6min
# [CV 5/5] END ...C=10, gamma=0.01, kernel=linear;, score=0.513 total time=10.9min
# [CV 2/5] END ......C=10, gamma=1, kernel=linear;, score=0.499 total time= 7.5min
# [CV 3/5] END ...C=10, gamma=0.01, kernel=linear;, score=0.510 total time=12.1min
# [CV 4/5] END ......C=10, gamma=1, kernel=linear;, score=0.476 total time= 7.2min
# [CV 5/5] END ....C=10, gamma=0.1, kernel=linear;, score=0.513 total time= 9.4min
# [CV 3/5] END ....C=10, gamma=0.1, kernel=linear;, score=0.510 total time=10.6min
# [CV 3/5] END ......C=10, gamma=1, kernel=linear;, score=0.510 total time= 9.3min
# [CV 5/5] END ......C=10, gamma=1, kernel=linear;, score=0.513 total time= 7.3min
# Best Parameters: {'C': 1, 'gamma': 'scale', 'kernel': 'linear'}
# Best Score: 0.5100976280663782
