# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split, GridSearchCV, StratifiedKFold
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report

# %%
DF_PATH = '../data/dataframes/telecom_churn_scaled.csv'
df = pd.read_csv(DF_PATH)
df.head()
# Out:
#    Unnamed: 0  AccountWeeks  DataUsage  CustServCalls   DayMins  DayCalls  \
# 0           0      0.676489   1.480204      -0.427932  1.566767  0.476643
# 1           1      0.149065   2.266072      -0.427932 -0.333738  1.124503
# 2           2      0.902529  -0.641642      -1.188218  1.168304  0.675985
# 3           3     -0.428590  -0.641642       0.332354  2.196596 -1.466936
# 4           4     -0.654629  -0.641642       1.092641 -0.240090  0.626149
#
#    MonthlyCharge  OverageFee  RoamMins  AvgMinPerCall  AvgDataUsagePerWeek  \
# 0       1.990727   -0.071584 -0.085008       0.735099             0.100484
# 1       1.564510   -0.107082  1.240482      -0.761059             0.269943
# 2      -0.262133   -1.574346  0.703121       0.359875            -0.164576
# 3       0.042307   -2.741846 -1.303026       3.201312            -0.164576
# 4      -0.931902   -1.037927 -0.049184      -0.540767            -0.164576
#
#    RoamMinsRatio  ComplaintIndex  Churn  ContractRenewal  DataPlan
# 0      -0.356334       -0.333213      0                1         1
# 1       0.223148        0.602388      0                1         1
# 2      -0.203610       -0.848993      0                1         0
# 3      -0.549400       -1.938814      0                0         0
# 4      -0.074740        0.129447      0                0         0

# %%
X = df.drop(columns=['Churn'])
y = df['Churn']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, stratify=y, shuffle=True, random_state=42)

# %%
# Instantiating the RandomForest Model with Parametrized Attributes
strat_k_fold = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

param_grid = {
    'n_estimators' : [10, 100, 1000],
    'criterion' : ['gini', 'entropy', 'log_loss'],
    'max_features' : ['sqrt', 'log2', None],
    'bootstrap' : [True, False],
}

grid_search = GridSearchCV(
    RandomForestClassifier(random_state=42, class_weight='balanced'),
    param_grid=param_grid,
    cv=strat_k_fold,
    verbose=3,
    n_jobs=-1,
    scoring='f1'
)

# Fitting the search
grid_search.fit(X_train, y_train)

# Printing statistic
print(f"Best Parameters: {grid_search.best_params_}")
print(f"Best F1-Score: {grid_search.best_score_:0.3f}")
# Out:
# Fitting 5 folds for each of 54 candidates, totalling 270 fits
# [CV 1/5] END bootstrap=True, criterion=gini, max_features=sqrt, n_estimators=10;, score=0.661 total time=   0.1s
# [CV 4/5] END bootstrap=True, criterion=gini, max_features=sqrt, n_estimators=10;, score=0.628 total time=   0.1s
# [CV 3/5] END bootstrap=True, criterion=gini, max_features=sqrt, n_estimators=10;, score=0.612 total time=   0.1s
# [CV 2/5] END bootstrap=True, criterion=gini, max_features=sqrt, n_estimators=10;, score=0.672 total time=   0.1s
# [CV 5/5] END bootstrap=True, criterion=gini, max_features=sqrt, n_estimators=10;, score=0.610 total time=   0.1s
# [CV 1/5] END bootstrap=True, criterion=gini, max_features=log2, n_estimators=100;, score=0.672 total time=   1.0s
# [CV 1/5] END bootstrap=True, criterion=gini, max_features=sqrt, n_estimators=100;, score=0.672 total time=   1.0s
# [CV 2/5] END bootstrap=True, criterion=gini, max_features=log2, n_estimators=100;, score=0.730 total time=   0.9s
# [CV 3/5] END bootstrap=True, criterion=gini, max_features=log2, n_estimators=100;, score=0.708 total time=   1.0s
# [CV 4/5] END bootstrap=True, criterion=gini, max_features=log2, n_estimators=100;, score=0.718 total time=   0.9s
# [CV 5/5] END bootstrap=True, criterion=gini, max_features=log2, n_estimators=100;, score=0.713 total time=   0.9s
# [CV 1/5] END bootstrap=True, criterion=gini, max_features=log2, n_estimators=10;, score=0.661 total time=   0.2s
# [CV 4/5] END bootstrap=True, criterion=gini, max_features=log2, n_estimators=10;, score=0.628 total time=   0.2s
# [CV 2/5] END bootstrap=True, criterion=gini, max_features=log2, n_estimators=10;, score=0.672 total time=   0.1s
# [CV 3/5] END bootstrap=True, criterion=gini, max_features=log2, n_estimators=10;, score=0.612 total time=   0.1s
# [CV 5/5] END bootstrap=True, criterion=gini, max_features=log2, n_estimators=10;, score=0.610 total time=   0.2s
# [CV 1/5] END bootstrap=True, criterion=gini, max_features=None, n_estimators=10;, score=0.746 total time=   0.4s
# [CV 5/5] END bootstrap=True, criterion=gini, max_features=None, n_estimators=10;, score=0.698 total time=   0.3s
# [CV 4/5] END bootstrap=True, criterion=gini, max_features=None, n_estimators=10;, score=0.687 total time=   0.4s
# [CV 2/5] END bootstrap=True, criterion=gini, max_features=None, n_estimators=10;, score=0.750 total time=   0.5s
# [CV 3/5] END bootstrap=True, criterion=gini, max_features=None, n_estimators=10;, score=0.682 total time=   0.4s
# [CV 3/5] END bootstrap=True, criterion=gini, max_features=sqrt, n_estimators=100;, score=0.708 total time=   1.2s
# [CV 4/5] END bootstrap=True, criterion=gini, max_features=sqrt, n_estimators=100;, score=0.718 total time=   1.3s
# [CV 5/5] END bootstrap=True, criterion=gini, max_features=sqrt, n_estimators=100;, score=0.713 total time=   1.4s
# [CV 2/5] END bootstrap=True, criterion=gini, max_features=sqrt, n_estimators=100;, score=0.730 total time=   1.4s
# [CV 3/5] END bootstrap=True, criterion=gini, max_features=None, n_estimators=100;, score=0.706 total time=   3.2s
# [CV 1/5] END bootstrap=True, criterion=entropy, max_features=sqrt, n_estimators=10;, score=0.614 total time=   0.1s
# [CV 2/5] END bootstrap=True, criterion=gini, max_features=None, n_estimators=100;, score=0.743 total time=   3.7s
# [CV 1/5] END bootstrap=True, criterion=gini, max_features=None, n_estimators=100;, score=0.748 total time=   3.7s
# [CV 2/5] END bootstrap=True, criterion=entropy, max_features=sqrt, n_estimators=10;, score=0.667 total time=   0.1s
# [CV 3/5] END bootstrap=True, criterion=entropy, max_features=sqrt, n_estimators=10;, score=0.619 total time=   0.1s
# [CV 4/5] END bootstrap=True, criterion=entropy, max_features=sqrt, n_estimators=10;, score=0.645 total time=   0.1s
# [CV 4/5] END bootstrap=True, criterion=gini, max_features=None, n_estimators=100;, score=0.737 total time=   3.5s
# [CV 5/5] END bootstrap=True, criterion=entropy, max_features=sqrt, n_estimators=10;, score=0.650 total time=   0.1s
# [CV 5/5] END bootstrap=True, criterion=gini, max_features=None, n_estimators=100;, score=0.712 total time=   4.3s
# [CV 3/5] END bootstrap=True, criterion=entropy, max_features=sqrt, n_estimators=100;, score=0.722 total time=   1.1s
# [CV 2/5] END bootstrap=True, criterion=entropy, max_features=sqrt, n_estimators=100;, score=0.756 total time=   1.1s
# [CV 4/5] END bootstrap=True, criterion=entropy, max_features=sqrt, n_estimators=100;, score=0.723 total time=   1.1s
# [CV 1/5] END bootstrap=True, criterion=entropy, max_features=sqrt, n_estimators=100;, score=0.713 total time=   1.2s
# [CV 5/5] END bootstrap=True, criterion=entropy, max_features=sqrt, n_estimators=100;, score=0.708 total time=   1.2s
# [CV 2/5] END bootstrap=True, criterion=gini, max_features=log2, n_estimators=1000;, score=0.735 total time=   9.1s
# [CV 4/5] END bootstrap=True, criterion=gini, max_features=log2, n_estimators=1000;, score=0.698 total time=   9.0s
# [CV 1/5] END bootstrap=True, criterion=gini, max_features=log2, n_estimators=1000;, score=0.692 total time=   9.2s
# [CV 5/5] END bootstrap=True, criterion=gini, max_features=log2, n_estimators=1000;, score=0.661 total time=   9.0s
# [CV 1/5] END bootstrap=True, criterion=entropy, max_features=log2, n_estimators=10;, score=0.614 total time=   0.1s
# [CV 3/5] END bootstrap=True, criterion=gini, max_features=log2, n_estimators=1000;, score=0.677 total time=   9.1s
# [CV 2/5] END bootstrap=True, criterion=entropy, max_features=log2, n_estimators=10;, score=0.667 total time=   0.1s
# [CV 3/5] END bootstrap=True, criterion=entropy, max_features=log2, n_estimators=10;, score=0.619 total time=   0.1s
# [CV 4/5] END bootstrap=True, criterion=entropy, max_features=log2, n_estimators=10;, score=0.645 total time=   0.1s
# [CV 5/5] END bootstrap=True, criterion=entropy, max_features=log2, n_estimators=10;, score=0.650 total time=   0.1s
# [CV 1/5] END bootstrap=True, criterion=entropy, max_features=log2, n_estimators=100;, score=0.713 total time=   1.0s
# [CV 3/5] END bootstrap=True, criterion=entropy, max_features=log2, n_estimators=100;, score=0.722 total time=   1.0s
# [CV 4/5] END bootstrap=True, criterion=entropy, max_features=log2, n_estimators=100;, score=0.723 total time=   1.0s
# [CV 2/5] END bootstrap=True, criterion=entropy, max_features=log2, n_estimators=100;, score=0.756 total time=   1.1s
# [CV 5/5] END bootstrap=True, criterion=entropy, max_features=log2, n_estimators=100;, score=0.708 total time=   1.1s
# [CV 5/5] END bootstrap=True, criterion=gini, max_features=sqrt, n_estimators=1000;, score=0.661 total time=  10.1s
# [CV 3/5] END bootstrap=True, criterion=gini, max_features=sqrt, n_estimators=1000;, score=0.677 total time=  10.2s
# [CV 1/5] END bootstrap=True, criterion=entropy, max_features=None, n_estimators=10;, score=0.722 total time=   0.4s
# [CV 2/5] END bootstrap=True, criterion=entropy, max_features=None, n_estimators=10;, score=0.745 total time=   0.4s
# [CV 3/5] END bootstrap=True, criterion=entropy, max_features=None, n_estimators=10;, score=0.702 total time=   0.4s
# [CV 4/5] END bootstrap=True, criterion=entropy, max_features=None, n_estimators=10;, score=0.667 total time=   0.4s
# [CV 4/5] END bootstrap=True, criterion=gini, max_features=sqrt, n_estimators=1000;, score=0.698 total time=  11.5s
# [CV 2/5] END bootstrap=True, criterion=gini, max_features=sqrt, n_estimators=1000;, score=0.735 total time=  11.5s
# [CV 5/5] END bootstrap=True, criterion=entropy, max_features=None, n_estimators=10;, score=0.677 total time=   0.4s
# [CV 1/5] END bootstrap=True, criterion=gini, max_features=sqrt, n_estimators=1000;, score=0.692 total time=  11.8s
# [CV 1/5] END bootstrap=True, criterion=entropy, max_features=None, n_estimators=100;, score=0.771 total time=   3.7s
# [CV 2/5] END bootstrap=True, criterion=entropy, max_features=None, n_estimators=100;, score=0.748 total time=   3.7s
# [CV 4/5] END bootstrap=True, criterion=entropy, max_features=None, n_estimators=100;, score=0.746 total time=   3.8s
# [CV 5/5] END bootstrap=True, criterion=entropy, max_features=None, n_estimators=100;, score=0.711 total time=   3.7s
# [CV 3/5] END bootstrap=True, criterion=entropy, max_features=None, n_estimators=100;, score=0.735 total time=   3.9s
# [CV 1/5] END bootstrap=True, criterion=entropy, max_features=sqrt, n_estimators=1000;, score=0.750 total time=  10.4s
# [CV 1/5] END bootstrap=True, criterion=log_loss, max_features=sqrt, n_estimators=10;, score=0.614 total time=   0.1s
# [CV 2/5] END bootstrap=True, criterion=log_loss, max_features=sqrt, n_estimators=10;, score=0.667 total time=   0.1s
# [CV 3/5] END bootstrap=True, criterion=log_loss, max_features=sqrt, n_estimators=10;, score=0.619 total time=   0.1s
# [CV 4/5] END bootstrap=True, criterion=log_loss, max_features=sqrt, n_estimators=10;, score=0.645 total time=   0.1s
# [CV 4/5] END bootstrap=True, criterion=entropy, max_features=sqrt, n_estimators=1000;, score=0.713 total time=  10.9s
# [CV 5/5] END bootstrap=True, criterion=log_loss, max_features=sqrt, n_estimators=10;, score=0.650 total time=   0.1s
# [CV 3/5] END bootstrap=True, criterion=entropy, max_features=sqrt, n_estimators=1000;, score=0.722 total time=  11.1s
# [CV 2/5] END bootstrap=True, criterion=entropy, max_features=sqrt, n_estimators=1000;, score=0.754 total time=  11.2s
# [CV 2/5] END bootstrap=True, criterion=log_loss, max_features=sqrt, n_estimators=100;, score=0.756 total time=   1.0s
# [CV 1/5] END bootstrap=True, criterion=log_loss, max_features=sqrt, n_estimators=100;, score=0.713 total time=   1.1s
# [CV 3/5] END bootstrap=True, criterion=log_loss, max_features=sqrt, n_estimators=100;, score=0.722 total time=   1.1s
# [CV 5/5] END bootstrap=True, criterion=entropy, max_features=sqrt, n_estimators=1000;, score=0.731 total time=  11.4s
# [CV 4/5] END bootstrap=True, criterion=log_loss, max_features=sqrt, n_estimators=100;, score=0.723 total time=   1.1s
# [CV 5/5] END bootstrap=True, criterion=log_loss, max_features=sqrt, n_estimators=100;, score=0.708 total time=   1.0s
# [CV 2/5] END bootstrap=True, criterion=entropy, max_features=log2, n_estimators=1000;, score=0.754 total time=   9.9s
# [CV 5/5] END bootstrap=True, criterion=entropy, max_features=log2, n_estimators=1000;, score=0.731 total time=   9.8s
# [CV 4/5] END bootstrap=True, criterion=entropy, max_features=log2, n_estimators=1000;, score=0.713 total time=   9.9s
# [CV 1/5] END bootstrap=True, criterion=log_loss, max_features=log2, n_estimators=10;, score=0.614 total time=   0.1s
# [CV 2/5] END bootstrap=True, criterion=log_loss, max_features=log2, n_estimators=10;, score=0.667 total time=   0.1s
# [CV 3/5] END bootstrap=True, criterion=log_loss, max_features=log2, n_estimators=10;, score=0.619 total time=   0.1s
# [CV 3/5] END bootstrap=True, criterion=entropy, max_features=log2, n_estimators=1000;, score=0.722 total time=  10.1s
# [CV 4/5] END bootstrap=True, criterion=log_loss, max_features=log2, n_estimators=10;, score=0.645 total time=   0.1s
# [CV 5/5] END bootstrap=True, criterion=log_loss, max_features=log2, n_estimators=10;, score=0.650 total time=   0.1s
# [CV 1/5] END bootstrap=True, criterion=entropy, max_features=log2, n_estimators=1000;, score=0.750 total time=  10.2s
# [CV 1/5] END bootstrap=True, criterion=log_loss, max_features=log2, n_estimators=100;, score=0.713 total time=   1.0s
# [CV 2/5] END bootstrap=True, criterion=log_loss, max_features=log2, n_estimators=100;, score=0.756 total time=   1.0s
# [CV 4/5] END bootstrap=True, criterion=log_loss, max_features=log2, n_estimators=100;, score=0.723 total time=   1.0s
# [CV 3/5] END bootstrap=True, criterion=log_loss, max_features=log2, n_estimators=100;, score=0.722 total time=   1.0s
# [CV 5/5] END bootstrap=True, criterion=log_loss, max_features=log2, n_estimators=100;, score=0.708 total time=   1.1s
# [CV 4/5] END bootstrap=True, criterion=log_loss, max_features=sqrt, n_estimators=1000;, score=0.713 total time=  10.4s
# [CV 1/5] END bootstrap=True, criterion=log_loss, max_features=sqrt, n_estimators=1000;, score=0.750 total time=  10.7s
# [CV 2/5] END bootstrap=True, criterion=log_loss, max_features=sqrt, n_estimators=1000;, score=0.754 total time=  10.6s
# [CV 5/5] END bootstrap=True, criterion=log_loss, max_features=sqrt, n_estimators=1000;, score=0.731 total time=   9.9s
# [CV 1/5] END bootstrap=True, criterion=log_loss, max_features=None, n_estimators=10;, score=0.722 total time=   0.4s
# [CV 3/5] END bootstrap=True, criterion=log_loss, max_features=None, n_estimators=10;, score=0.702 total time=   0.3s
# [CV 2/5] END bootstrap=True, criterion=log_loss, max_features=None, n_estimators=10;, score=0.745 total time=   0.4s
# [CV 4/5] END bootstrap=True, criterion=log_loss, max_features=None, n_estimators=10;, score=0.667 total time=   0.3s
# [CV 5/5] END bootstrap=True, criterion=log_loss, max_features=None, n_estimators=10;, score=0.677 total time=   0.3s
# [CV 3/5] END bootstrap=True, criterion=log_loss, max_features=sqrt, n_estimators=1000;, score=0.722 total time=  11.5s
# [CV 4/5] END bootstrap=True, criterion=log_loss, max_features=log2, n_estimators=1000;, score=0.713 total time=   9.8s
# [CV 1/5] END bootstrap=True, criterion=log_loss, max_features=log2, n_estimators=1000;, score=0.750 total time=  10.0s
# [CV 5/5] END bootstrap=True, criterion=log_loss, max_features=log2, n_estimators=1000;, score=0.731 total time=   9.8s
# [CV 2/5] END bootstrap=True, criterion=log_loss, max_features=log2, n_estimators=1000;, score=0.754 total time=  10.0s
# [CV 3/5] END bootstrap=True, criterion=log_loss, max_features=log2, n_estimators=1000;, score=0.722 total time=   9.9s
# [CV 3/5] END bootstrap=True, criterion=log_loss, max_features=None, n_estimators=100;, score=0.735 total time=   3.3s
# [CV 1/5] END bootstrap=False, criterion=gini, max_features=sqrt, n_estimators=10;, score=0.667 total time=   0.1s
# [CV 2/5] END bootstrap=True, criterion=log_loss, max_features=None, n_estimators=100;, score=0.748 total time=   3.6s
# [CV 1/5] END bootstrap=True, criterion=log_loss, max_features=None, n_estimators=100;, score=0.771 total time=   3.6s
# [CV 2/5] END bootstrap=False, criterion=gini, max_features=sqrt, n_estimators=10;, score=0.691 total time=   0.1s
# [CV 3/5] END bootstrap=False, criterion=gini, max_features=sqrt, n_estimators=10;, score=0.623 total time=   0.1s
# [CV 4/5] END bootstrap=False, criterion=gini, max_features=sqrt, n_estimators=10;, score=0.693 total time=   0.1s
# [CV 5/5] END bootstrap=False, criterion=gini, max_features=sqrt, n_estimators=10;, score=0.645 total time=   0.1s
# [CV 4/5] END bootstrap=True, criterion=log_loss, max_features=None, n_estimators=100;, score=0.746 total time=   3.5s
# [CV 5/5] END bootstrap=True, criterion=log_loss, max_features=None, n_estimators=100;, score=0.711 total time=   3.6s
# [CV 2/5] END bootstrap=False, criterion=gini, max_features=sqrt, n_estimators=100;, score=0.735 total time=   1.3s
# [CV 3/5] END bootstrap=False, criterion=gini, max_features=sqrt, n_estimators=100;, score=0.682 total time=   1.3s
# [CV 1/5] END bootstrap=False, criterion=gini, max_features=sqrt, n_estimators=100;, score=0.692 total time=   1.3s
# [CV 4/5] END bootstrap=False, criterion=gini, max_features=sqrt, n_estimators=100;, score=0.692 total time=   1.3s
# [CV 5/5] END bootstrap=False, criterion=gini, max_features=sqrt, n_estimators=100;, score=0.702 total time=   1.5s
# [CV 2/5] END bootstrap=True, criterion=gini, max_features=None, n_estimators=1000;, score=0.738 total time=  34.2s
# [CV 1/5] END bootstrap=False, criterion=gini, max_features=log2, n_estimators=10;, score=0.667 total time=   0.1s
# [CV 4/5] END bootstrap=True, criterion=gini, max_features=None, n_estimators=1000;, score=0.741 total time=  34.3s
# [CV 2/5] END bootstrap=False, criterion=gini, max_features=log2, n_estimators=10;, score=0.691 total time=   0.2s
# [CV 4/5] END bootstrap=False, criterion=gini, max_features=log2, n_estimators=10;, score=0.693 total time=   0.1s
# [CV 3/5] END bootstrap=False, criterion=gini, max_features=log2, n_estimators=10;, score=0.623 total time=   0.2s
# [CV 5/5] END bootstrap=False, criterion=gini, max_features=log2, n_estimators=10;, score=0.645 total time=   0.1s
# [CV 5/5] END bootstrap=True, criterion=gini, max_features=None, n_estimators=1000;, score=0.702 total time=  34.8s
# [CV 3/5] END bootstrap=True, criterion=gini, max_features=None, n_estimators=1000;, score=0.721 total time=  35.0s
# [CV 1/5] END bootstrap=True, criterion=gini, max_features=None, n_estimators=1000;, score=0.738 total time=  36.1s
# [CV 1/5] END bootstrap=False, criterion=gini, max_features=log2, n_estimators=100;, score=0.692 total time=   1.4s
# [CV 2/5] END bootstrap=False, criterion=gini, max_features=log2, n_estimators=100;, score=0.735 total time=   1.4s
# [CV 4/5] END bootstrap=False, criterion=gini, max_features=log2, n_estimators=100;, score=0.692 total time=   1.3s
# [CV 3/5] END bootstrap=False, criterion=gini, max_features=log2, n_estimators=100;, score=0.682 total time=   1.4s
# [CV 5/5] END bootstrap=False, criterion=gini, max_features=log2, n_estimators=100;, score=0.702 total time=   1.4s
# [CV 3/5] END bootstrap=False, criterion=gini, max_features=sqrt, n_estimators=1000;, score=0.730 total time=  12.3s
# [CV 4/5] END bootstrap=False, criterion=gini, max_features=sqrt, n_estimators=1000;, score=0.731 total time=  12.7s
# [CV 1/5] END bootstrap=False, criterion=gini, max_features=None, n_estimators=10;, score=0.632 total time=   0.5s
# [CV 2/5] END bootstrap=False, criterion=gini, max_features=sqrt, n_estimators=1000;, score=0.735 total time=  13.1s
# [CV 1/5] END bootstrap=False, criterion=gini, max_features=sqrt, n_estimators=1000;, score=0.716 total time=  13.4s
# [CV 2/5] END bootstrap=False, criterion=gini, max_features=None, n_estimators=10;, score=0.713 total time=   0.6s
# [CV 3/5] END bootstrap=False, criterion=gini, max_features=None, n_estimators=10;, score=0.627 total time=   0.6s
# [CV 4/5] END bootstrap=False, criterion=gini, max_features=None, n_estimators=10;, score=0.654 total time=   0.5s
# [CV 5/5] END bootstrap=False, criterion=gini, max_features=None, n_estimators=10;, score=0.641 total time=   0.5s
# [CV 5/5] END bootstrap=False, criterion=gini, max_features=sqrt, n_estimators=1000;, score=0.711 total time=  13.4s
# [CV 2/5] END bootstrap=False, criterion=gini, max_features=log2, n_estimators=1000;, score=0.735 total time=  13.1s
# [CV 1/5] END bootstrap=False, criterion=gini, max_features=log2, n_estimators=1000;, score=0.716 total time=  13.8s
# [CV 4/5] END bootstrap=False, criterion=gini, max_features=log2, n_estimators=1000;, score=0.731 total time=  13.6s
# [CV 3/5] END bootstrap=False, criterion=gini, max_features=log2, n_estimators=1000;, score=0.730 total time=  13.6s
# [CV 2/5] END bootstrap=True, criterion=entropy, max_features=None, n_estimators=1000;, score=0.761 total time=  36.0s
# [CV 1/5] END bootstrap=True, criterion=entropy, max_features=None, n_estimators=1000;, score=0.786 total time=  36.7s
# [CV 5/5] END bootstrap=False, criterion=gini, max_features=log2, n_estimators=1000;, score=0.711 total time=  13.5s
# [CV 1/5] END bootstrap=False, criterion=entropy, max_features=sqrt, n_estimators=10;, score=0.688 total time=   0.2s
# [CV 2/5] END bootstrap=False, criterion=entropy, max_features=sqrt, n_estimators=10;, score=0.697 total time=   0.2s
# [CV 3/5] END bootstrap=False, criterion=entropy, max_features=sqrt, n_estimators=10;, score=0.707 total time=   0.2s
# [CV 4/5] END bootstrap=False, criterion=entropy, max_features=sqrt, n_estimators=10;, score=0.676 total time=   0.2s
# [CV 5/5] END bootstrap=False, criterion=entropy, max_features=sqrt, n_estimators=10;, score=0.712 total time=   0.2s
# [CV 4/5] END bootstrap=False, criterion=gini, max_features=None, n_estimators=100;, score=0.667 total time=   4.7s
# [CV 3/5] END bootstrap=False, criterion=gini, max_features=None, n_estimators=100;, score=0.627 total time=   5.2s
# [CV 2/5] END bootstrap=False, criterion=gini, max_features=None, n_estimators=100;, score=0.704 total time=   5.4s
# [CV 1/5] END bootstrap=False, criterion=gini, max_features=None, n_estimators=100;, score=0.650 total time=   5.5s
# [CV 5/5] END bootstrap=True, criterion=entropy, max_features=None, n_estimators=1000;, score=0.721 total time=  37.4s
# [CV 4/5] END bootstrap=True, criterion=entropy, max_features=None, n_estimators=1000;, score=0.750 total time=  37.4s
# [CV 5/5] END bootstrap=False, criterion=gini, max_features=None, n_estimators=100;, score=0.645 total time=   5.5s
# [CV 3/5] END bootstrap=True, criterion=entropy, max_features=None, n_estimators=1000;, score=0.721 total time=  38.1s
# [CV 1/5] END bootstrap=False, criterion=entropy, max_features=sqrt, n_estimators=100;, score=0.759 total time=   1.6s
# [CV 2/5] END bootstrap=False, criterion=entropy, max_features=sqrt, n_estimators=100;, score=0.742 total time=   1.6s
# [CV 1/5] END bootstrap=False, criterion=entropy, max_features=log2, n_estimators=10;, score=0.688 total time=   0.2s
# [CV 3/5] END bootstrap=False, criterion=entropy, max_features=sqrt, n_estimators=100;, score=0.739 total time=   1.6s
# [CV 2/5] END bootstrap=False, criterion=entropy, max_features=log2, n_estimators=10;, score=0.697 total time=   0.2s
# [CV 5/5] END bootstrap=False, criterion=entropy, max_features=sqrt, n_estimators=100;, score=0.742 total time=   1.4s
# [CV 4/5] END bootstrap=False, criterion=entropy, max_features=sqrt, n_estimators=100;, score=0.752 total time=   1.5s
# [CV 3/5] END bootstrap=False, criterion=entropy, max_features=log2, n_estimators=10;, score=0.707 total time=   0.2s
# [CV 4/5] END bootstrap=False, criterion=entropy, max_features=log2, n_estimators=10;, score=0.676 total time=   0.2s
# [CV 5/5] END bootstrap=False, criterion=entropy, max_features=log2, n_estimators=10;, score=0.712 total time=   0.2s
# [CV 1/5] END bootstrap=False, criterion=entropy, max_features=log2, n_estimators=100;, score=0.759 total time=   2.4s
# [CV 5/5] END bootstrap=False, criterion=entropy, max_features=log2, n_estimators=100;, score=0.742 total time=   2.4s
# [CV 4/5] END bootstrap=False, criterion=entropy, max_features=log2, n_estimators=100;, score=0.752 total time=   2.4s
# [CV 2/5] END bootstrap=False, criterion=entropy, max_features=log2, n_estimators=100;, score=0.742 total time=   2.5s
# [CV 3/5] END bootstrap=False, criterion=entropy, max_features=log2, n_estimators=100;, score=0.739 total time=   2.5s
# [CV 5/5] END bootstrap=True, criterion=log_loss, max_features=None, n_estimators=1000;, score=0.721 total time=  38.6s
# [CV 4/5] END bootstrap=True, criterion=log_loss, max_features=None, n_estimators=1000;, score=0.750 total time=  38.8s
# [CV 1/5] END bootstrap=False, criterion=entropy, max_features=None, n_estimators=10;, score=0.671 total time=   0.9s
# [CV 2/5] END bootstrap=False, criterion=entropy, max_features=None, n_estimators=10;, score=0.620 total time=   1.0s
# [CV 3/5] END bootstrap=True, criterion=log_loss, max_features=None, n_estimators=1000;, score=0.721 total time=  39.8s
# [CV 2/5] END bootstrap=True, criterion=log_loss, max_features=None, n_estimators=1000;, score=0.761 total time=  39.9s
# [CV 1/5] END bootstrap=True, criterion=log_loss, max_features=None, n_estimators=1000;, score=0.786 total time=  40.5s
# [CV 3/5] END bootstrap=False, criterion=entropy, max_features=None, n_estimators=10;, score=0.628 total time=   1.0s
# [CV 4/5] END bootstrap=False, criterion=entropy, max_features=None, n_estimators=10;, score=0.662 total time=   0.8s
# [CV 5/5] END bootstrap=False, criterion=entropy, max_features=None, n_estimators=10;, score=0.635 total time=   0.9s
# [CV 2/5] END bootstrap=False, criterion=entropy, max_features=sqrt, n_estimators=1000;, score=0.741 total time=  23.0s
# [CV 4/5] END bootstrap=False, criterion=entropy, max_features=sqrt, n_estimators=1000;, score=0.742 total time=  22.9s
# [CV 3/5] END bootstrap=False, criterion=entropy, max_features=sqrt, n_estimators=1000;, score=0.734 total time=  23.1s
# [CV 1/5] END bootstrap=False, criterion=entropy, max_features=sqrt, n_estimators=1000;, score=0.759 total time=  23.7s
# [CV 5/5] END bootstrap=False, criterion=entropy, max_features=sqrt, n_estimators=1000;, score=0.733 total time=  22.9s
# [CV 1/5] END bootstrap=False, criterion=entropy, max_features=log2, n_estimators=1000;, score=0.759 total time=  23.0s
# [CV 1/5] END bootstrap=False, criterion=entropy, max_features=None, n_estimators=100;, score=0.680 total time=   8.5s
# [CV 1/5] END bootstrap=False, criterion=log_loss, max_features=sqrt, n_estimators=10;, score=0.688 total time=   0.2s
# [CV 4/5] END bootstrap=False, criterion=entropy, max_features=None, n_estimators=100;, score=0.667 total time=   8.0s
# [CV 2/5] END bootstrap=False, criterion=log_loss, max_features=sqrt, n_estimators=10;, score=0.697 total time=   0.2s
# [CV 4/5] END bootstrap=False, criterion=entropy, max_features=log2, n_estimators=1000;, score=0.742 total time=  23.2s
# [CV 3/5] END bootstrap=False, criterion=log_loss, max_features=sqrt, n_estimators=10;, score=0.707 total time=   0.2s
# [CV 4/5] END bootstrap=False, criterion=log_loss, max_features=sqrt, n_estimators=10;, score=0.676 total time=   0.2s
# [CV 5/5] END bootstrap=False, criterion=log_loss, max_features=sqrt, n_estimators=10;, score=0.712 total time=   0.2s
# [CV 2/5] END bootstrap=False, criterion=entropy, max_features=log2, n_estimators=1000;, score=0.741 total time=  23.6s
# [CV 5/5] END bootstrap=False, criterion=entropy, max_features=log2, n_estimators=1000;, score=0.733 total time=  23.6s
# [CV 5/5] END bootstrap=False, criterion=entropy, max_features=None, n_estimators=100;, score=0.623 total time=   8.4s
# [CV 3/5] END bootstrap=False, criterion=entropy, max_features=log2, n_estimators=1000;, score=0.734 total time=  23.9s
# [CV 2/5] END bootstrap=False, criterion=entropy, max_features=None, n_estimators=100;, score=0.604 total time=   9.2s
# [CV 3/5] END bootstrap=False, criterion=entropy, max_features=None, n_estimators=100;, score=0.632 total time=   9.4s
# [CV 2/5] END bootstrap=False, criterion=log_loss, max_features=sqrt, n_estimators=100;, score=0.742 total time=   2.3s
# [CV 3/5] END bootstrap=False, criterion=log_loss, max_features=sqrt, n_estimators=100;, score=0.739 total time=   2.2s
# [CV 4/5] END bootstrap=False, criterion=log_loss, max_features=sqrt, n_estimators=100;, score=0.752 total time=   2.2s
# [CV 1/5] END bootstrap=False, criterion=log_loss, max_features=sqrt, n_estimators=100;, score=0.759 total time=   2.4s
# [CV 1/5] END bootstrap=False, criterion=log_loss, max_features=log2, n_estimators=10;, score=0.688 total time=   0.2s
# [CV 2/5] END bootstrap=False, criterion=log_loss, max_features=log2, n_estimators=10;, score=0.697 total time=   0.3s
# [CV 3/5] END bootstrap=False, criterion=log_loss, max_features=log2, n_estimators=10;, score=0.707 total time=   0.2s
# [CV 4/5] END bootstrap=False, criterion=log_loss, max_features=log2, n_estimators=10;, score=0.676 total time=   0.2s
# [CV 5/5] END bootstrap=False, criterion=log_loss, max_features=log2, n_estimators=10;, score=0.712 total time=   0.2s
# [CV 5/5] END bootstrap=False, criterion=log_loss, max_features=sqrt, n_estimators=100;, score=0.742 total time=   2.5s
# [CV 2/5] END bootstrap=False, criterion=log_loss, max_features=log2, n_estimators=100;, score=0.742 total time=   2.2s
# [CV 1/5] END bootstrap=False, criterion=log_loss, max_features=log2, n_estimators=100;, score=0.759 total time=   2.3s
# [CV 4/5] END bootstrap=False, criterion=log_loss, max_features=log2, n_estimators=100;, score=0.752 total time=   2.1s
# [CV 3/5] END bootstrap=False, criterion=log_loss, max_features=log2, n_estimators=100;, score=0.739 total time=   2.5s
# [CV 5/5] END bootstrap=False, criterion=log_loss, max_features=log2, n_estimators=100;, score=0.742 total time=   2.5s
# [CV 2/5] END bootstrap=False, criterion=log_loss, max_features=sqrt, n_estimators=1000;, score=0.741 total time=  21.7s
# [CV 4/5] END bootstrap=False, criterion=log_loss, max_features=sqrt, n_estimators=1000;, score=0.742 total time=  21.4s
# [CV 5/5] END bootstrap=False, criterion=log_loss, max_features=sqrt, n_estimators=1000;, score=0.733 total time=  21.5s
# [CV 1/5] END bootstrap=False, criterion=log_loss, max_features=None, n_estimators=10;, score=0.671 total time=   0.9s
# [CV 2/5] END bootstrap=False, criterion=log_loss, max_features=None, n_estimators=10;, score=0.620 total time=   0.9s
# [CV 3/5] END bootstrap=False, criterion=log_loss, max_features=None, n_estimators=10;, score=0.628 total time=   1.0s
# [CV 4/5] END bootstrap=False, criterion=log_loss, max_features=None, n_estimators=10;, score=0.662 total time=   0.8s
# [CV 3/5] END bootstrap=False, criterion=log_loss, max_features=sqrt, n_estimators=1000;, score=0.734 total time=  23.6s
# [CV 5/5] END bootstrap=False, criterion=log_loss, max_features=None, n_estimators=10;, score=0.635 total time=   0.9s
# [CV 1/5] END bootstrap=False, criterion=log_loss, max_features=sqrt, n_estimators=1000;, score=0.759 total time=  24.0s
# [CV 2/5] END bootstrap=False, criterion=log_loss, max_features=log2, n_estimators=1000;, score=0.741 total time=  21.9s
# [CV 3/5] END bootstrap=False, criterion=log_loss, max_features=log2, n_estimators=1000;, score=0.734 total time=  22.1s
# [CV 1/5] END bootstrap=False, criterion=log_loss, max_features=log2, n_estimators=1000;, score=0.759 total time=  22.3s
# [CV 5/5] END bootstrap=False, criterion=log_loss, max_features=log2, n_estimators=1000;, score=0.733 total time=  22.5s
# [CV 4/5] END bootstrap=False, criterion=log_loss, max_features=log2, n_estimators=1000;, score=0.742 total time=  22.7s
# [CV 4/5] END bootstrap=False, criterion=log_loss, max_features=None, n_estimators=100;, score=0.667 total time=   7.8s
# [CV 1/5] END bootstrap=False, criterion=log_loss, max_features=None, n_estimators=100;, score=0.680 total time=   8.4s
# [CV 2/5] END bootstrap=False, criterion=log_loss, max_features=None, n_estimators=100;, score=0.604 total time=   9.0s
# [CV 5/5] END bootstrap=False, criterion=log_loss, max_features=None, n_estimators=100;, score=0.623 total time=   8.6s
# [CV 3/5] END bootstrap=False, criterion=log_loss, max_features=None, n_estimators=100;, score=0.632 total time=   9.3s
# [CV 4/5] END bootstrap=False, criterion=gini, max_features=None, n_estimators=1000;, score=0.659 total time= 1.1min
# [CV 3/5] END bootstrap=False, criterion=gini, max_features=None, n_estimators=1000;, score=0.627 total time= 1.2min
# [CV 5/5] END bootstrap=False, criterion=gini, max_features=None, n_estimators=1000;, score=0.645 total time= 1.2min
# [CV 1/5] END bootstrap=False, criterion=gini, max_features=None, n_estimators=1000;, score=0.642 total time= 1.3min
# [CV 2/5] END bootstrap=False, criterion=gini, max_features=None, n_estimators=1000;, score=0.720 total time= 1.3min
# [CV 4/5] END bootstrap=False, criterion=entropy, max_features=None, n_estimators=1000;, score=0.662 total time= 1.1min
# [CV 5/5] END bootstrap=False, criterion=entropy, max_features=None, n_estimators=1000;, score=0.623 total time= 1.2min
# [CV 1/5] END bootstrap=False, criterion=entropy, max_features=None, n_estimators=1000;, score=0.689 total time= 1.2min
# [CV 3/5] END bootstrap=False, criterion=entropy, max_features=None, n_estimators=1000;, score=0.632 total time= 1.2min
# [CV 2/5] END bootstrap=False, criterion=entropy, max_features=None, n_estimators=1000;, score=0.616 total time= 1.2min
# [CV 4/5] END bootstrap=False, criterion=log_loss, max_features=None, n_estimators=1000;, score=0.662 total time=  48.7s
# [CV 1/5] END bootstrap=False, criterion=log_loss, max_features=None, n_estimators=1000;, score=0.689 total time=  51.1s
# [CV 5/5] END bootstrap=False, criterion=log_loss, max_features=None, n_estimators=1000;, score=0.623 total time=  50.5s
# [CV 3/5] END bootstrap=False, criterion=log_loss, max_features=None, n_estimators=1000;, score=0.632 total time=  53.5s
# [CV 2/5] END bootstrap=False, criterion=log_loss, max_features=None, n_estimators=1000;, score=0.616 total time=  53.7s
# Best Parameters: {'bootstrap': True, 'criterion': 'entropy', 'max_features': None, 'n_estimators': 1000}
# Best F1-Score: 0.747

# %%
# Instantiating a RM clasifier based on the best output of the grid search
bootstrap = grid_search.best_estimator_.get_params()['bootstrap']
criterion =  grid_search.best_estimator_.get_params()['criterion']
max_features =  grid_search.best_estimator_.get_params()['max_features']
n_estimators =  grid_search.best_estimator_.get_params()['n_estimators']

rf_classifier = RandomForestClassifier(
    bootstrap=bootstrap,
    criterion=criterion,
    max_features= max_features,
    n_estimators=n_estimators,
    class_weight='balanced',
    random_state=42,
    verbose=1
)
rf_classifier.fit(X_train, y_train)

preds = rf_classifier.predict(X_test)
results = classification_report(y_true=y_test, y_pred=preds, output_dict=True)
results
# Out:
# [Parallel(n_jobs=1)]: Done  49 tasks      | elapsed:    1.2s
# [Parallel(n_jobs=1)]: Done 199 tasks      | elapsed:    4.7s
# [Parallel(n_jobs=1)]: Done 449 tasks      | elapsed:   10.7s
# [Parallel(n_jobs=1)]: Done 799 tasks      | elapsed:   18.9s
# [Parallel(n_jobs=1)]: Done 1000 out of 1000 | elapsed:   23.7s finished
# [Parallel(n_jobs=1)]: Done  49 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=1)]: Done 199 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=1)]: Done 449 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=1)]: Done 799 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=1)]: Done 1000 out of 1000 | elapsed:    0.1s finished
# {'0': {'precision': 0.9359190556492412,
#   'recall': 0.9736842105263158,
#   'f1-score': 0.9544282029234737,
#   'support': 570.0},
#  '1': {'precision': 0.7972972972972973,
#   'recall': 0.6082474226804123,
#   'f1-score': 0.6900584795321637,
#   'support': 97.0},
#  'accuracy': 0.9205397301349325,
#  'macro avg': {'precision': 0.8666081764732692,
#   'recall': 0.7909658166033641,
#   'f1-score': 0.8222433412278187,
#   'support': 667.0},
#  'weighted avg': {'precision': 0.9157596695021069,
#   'recall': 0.9205397301349325,
#   'f1-score': 0.9159816314557719,
#   'support': 667.0}}
